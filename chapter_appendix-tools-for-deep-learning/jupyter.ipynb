# %% [markdown]
# <a href="https://colab.research.google.com/github/Gagan021-5/Colab/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sklearn

# %%
from sklearn.datasets import load_diabetes

# %%
x,y = load_diabetes(return_X_y=True)

# %%
x
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test ,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((353, 10), (89, 10))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
reg = lr.fit(x_train,y_train)

# %%
yprd = reg.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,yprd)
# Out:
# 0.4526027629719195

# %%
reg.coef_
# Out:
# array([  37.90402135, -241.96436231,  542.42875852,  347.70384391,
#        -931.48884588,  518.06227698,  163.41998299,  275.31790158,
#         736.1988589 ,   48.67065743])

# %%
reg.intercept_
# Out:
# np.float64(151.34560453985995)

# %% [markdown]
# ## Making own LR model by Mathematical equations

# %%
class MyLR:

  def __init__(self):
    self.coef = None
    self.intercept = None

  def fit(self,x_train,y_train):
    x_train = np.insert(x_train,0,1,axis=1)
    betas = np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)
    self.intercept= betas[0]
    self.coef_ = betas[1:]


  def predict(self,x_test):
   yprd = np.dot(x_test,self.coeff_) + (self.intercept_)
   pass

# %%
lr = MyLR()

# %%
lr.fit(x_train,y_train)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
np.insert(x_train,0,1,axis=1).shape
# Out:
# (353, 11)

# %%
yprd = lr.predict(x_test)

# %%
r2_score(y_test,yprd)
# Out:
# 0.4526027629719195
